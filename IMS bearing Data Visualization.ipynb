# %%
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Test-1
#
# - Channel Arrangement: Bearing 1 – Ch 1&2; Bearing 2 – Ch 3&4;Bearing 3 – Ch 5&6; Bearing 4 – Ch 7&8.
# - At the end of the test-to-failure experiment, **inner race defect** occurred in **bearing 3** and **roller element** defect in **bearing 4**.

# %%
test_no=1

df1 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_1_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df2 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_2_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df3 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_3_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df4 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_4_Test_{}.csv".format(test_no),index_col='Unnamed: 0')

df1.index = pd.to_datetime(df1.index)

# %%
for i,col in enumerate(df1.columns):  
    
        plt.figure(figsize=(10, 5))
        plt.plot(df1.index,df1[col])
        plt.plot(df1.index,df2[col])
        plt.plot(df1.index,df3[col])
        plt.plot(df1.index,df4[col])

        plt.legend(['bearing-1','bearing-2','bearing-3','bearing-4'])

        plt.xlabel("Date-Time")
        plt.ylabel(col)
        plt.title(col)
        plt.show()

# %% [markdown]
# ## Saving Inner race fault

# %%
df_irf=df3['2003-11-21 00:32:00':'2003-11-24 18:22:00']
fault=[]
for i in range (0,len(df_irf)):
    fault.append('Inner Race')

df_irf['Fault']=fault
df_irf
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\1442353547.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irf['Fault']=fault
#                        Max    Min      Mean       Std       RMS  Skewness  \
# 2003-11-21 00:34:00  0.427 -0.957 -0.114388  0.113003  0.160790  0.002204
# 2003-11-21 00:44:00  0.630 -0.854 -0.114292  0.112194  0.160155 -0.017072
# 2003-11-21 00:54:00  0.645 -0.718 -0.114115  0.111576  0.159596  0.048754
# 2003-11-21 01:04:00  0.815 -0.728 -0.115024  0.110413  0.159439  0.060862
# 2003-11-21 01:14:00  0.474 -0.710 -0.115375  0.113216  0.161644 -0.018933
# ...                    ...    ...       ...       ...       ...       ...
# 2003-11-24 17:37:00  0.786 -1.250 -0.115312  0.138938  0.180554 -0.111261
# ...

# %%
df_irf.to_csv('database\\tratados\\inner_race_fault.csv',index=False)

# %% [markdown]
# ## Saving Roller Element fault

# %%
df_ref=df4['2003-11-21 00:32:00':'2003-11-24 18:22:00']
fault=[]
for i in range (0,len(df_ref)):
    fault.append('Roller Element')

df_ref['Fault']=fault
df_ref
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\1836188734.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ref['Fault']=fault
#                        Max    Min      Mean       Std       RMS  Skewness  \
# 2003-11-21 00:34:00  1.282 -1.396 -0.115392  0.103224  0.154822  0.028321
# 2003-11-21 00:44:00  1.152 -1.108 -0.114562  0.107756  0.157274  0.103448
# 2003-11-21 00:54:00  0.972 -1.270 -0.112217  0.109194  0.156574 -0.088235
# 2003-11-21 01:04:00  0.945 -1.147 -0.113799  0.102681  0.153275 -0.001167
# 2003-11-21 01:14:00  1.096 -1.228 -0.114494  0.106910  0.156646  0.114157
# ...                    ...    ...       ...       ...       ...       ...
# 2003-11-24 17:37:00  0.701 -0.764 -0.114628  0.131560  0.174490  0.134774
# ...

# %%
df_ref.to_csv('database\\tratados\\roller_element_fault.csv',index=False)

# %% [markdown]
# # Test 2
#
# - Channel Arrangement: Bearing 1 – Ch 1; Bearing2 – Ch 2; Bearing3 – Ch3; Bearing 4 – Ch 4.
# - At the end of the test-to-failure experiment, outer race failure occurred in bearing 1.

# %%
test_no=2

df1 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_1_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df2 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_2_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df3 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_3_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df4 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_4_Test_{}.csv".format(test_no),index_col='Unnamed: 0')

df1.index = pd.to_datetime(df1.index)

for i,col in enumerate(df1.columns):  
    
        plt.figure(figsize=(10, 5))
        plt.plot(df1.index,df1[col])
        plt.plot(df1.index,df2[col])
        plt.plot(df1.index,df3[col])
        plt.plot(df1.index,df4[col])

        plt.legend(['bearing-1','bearing-2','bearing-3','bearing-4'])

        plt.xlabel("Date-Time")
        plt.ylabel(col)
        plt.title(col)
        plt.show()

# %% [markdown]
# ## Saving Outer Race Fault

# %%
df_orf=df1['2004-02-17 12:32:00':'2004-02-19 00:42:00']
fault=[]
for i in range (0,len(df_orf)):
    fault.append('Outer Race')

df_orf['Fault']=fault

df_orf.to_csv('database\\tratados\\outer_race_fault_test_2.csv',index=False)  
df_orf
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\1485379692.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_orf['Fault']=fault
#                        Max    Min      Mean       Std       RMS  Skewness  \
# 2004-02-17 12:32:00  0.789 -0.781 -0.001874  0.162117  0.162124 -0.076375
# 2004-02-17 12:42:00  0.803 -0.723 -0.001712  0.155821  0.155826 -0.087399
# 2004-02-17 12:52:00  0.879 -0.725 -0.002833  0.156768  0.156790 -0.082349
# 2004-02-17 13:02:00  0.784 -0.754 -0.002073  0.154166  0.154177 -0.050836
# 2004-02-17 13:12:00  0.854 -0.698 -0.001955  0.155019  0.155028 -0.079743
# ...                    ...    ...       ...       ...       ...       ...
# 2004-02-19 00:02:00  0.955 -1.118 -0.001586  0.215437  0.215437 -0.080072
# ...

# %% [markdown]
# # Test 3
# - Bearing1 – Ch 1; Bearing2 – Ch 2; Bearing3 – Ch3; Bearing4 – Ch4
# - At the end of the test-to-failure experiment, outer race failure occurred in bearing 3.

# %%
test_no=3

df1 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_1_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df2 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_2_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df3 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_3_Test_{}.csv".format(test_no),index_col='Unnamed: 0')
df4 = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_4_Test_{}.csv".format(test_no),index_col='Unnamed: 0')

df1.index = pd.to_datetime(df1.index)

for i,col in enumerate(df1.columns):  
    
        plt.figure(figsize=(10, 5))
        plt.plot(df1.index,df1[col])
        plt.plot(df1.index,df2[col])
        plt.plot(df1.index,df3[col])
        plt.plot(df1.index,df4[col])

        plt.legend(['bearing-1','bearing-2','bearing-3','bearing-4'])

        plt.xlabel("Date-Time")
        plt.ylabel(col)
        plt.title(col)
        plt.show()

# %% [markdown]
# ## Saving Outer Race Fault

# %%
df3
# Out:
#                        Max    Min      Mean       Std       RMS  Skewness  \
# 2004-03-04 09:27:00  0.361 -0.310 -0.005148  0.066192  0.066390  0.083449
# 2004-03-04 09:32:00  0.295 -0.295 -0.006310  0.065986  0.066285  0.011828
# 2004-03-04 09:42:00  0.286 -0.286 -0.001293  0.069176  0.069186  0.049056
# 2004-03-04 09:52:00  0.349 -0.310 -0.002280  0.068600  0.068637  0.002209
# 2004-03-04 10:02:00  0.388 -0.374 -0.001727  0.067449  0.067469  0.031884
# ...                    ...    ...       ...       ...       ...       ...
# 2004-04-18 02:02:00  3.167 -5.000  0.017613  0.495062  0.495363 -1.648364
# 2004-04-18 02:12:00  2.378 -3.899 -0.002114  0.454472  0.454466 -0.656841
# 2004-04-18 02:22:00  4.346 -5.000 -0.079840  0.584635  0.590047 -0.426006
# 2004-04-18 02:32:00  4.998 -5.000  0.052137  0.756990  0.758765 -0.220131
# 2004-04-18 02:42:00  0.007  0.000  0.003663  0.001520  0.003966 -0.135492
#
#                       Kurtosis  Crest Factor  Form Factor
# ...

# %%
df_orf=df3['2004-04-15 12:32:00':'2004-04-18 00:42:00']
fault=[]
for i in range (0,len(df_orf)):
    fault.append('Outer Race')

df_orf['Fault']=fault

df_orf.to_csv('database\\tratados\\outer_race_fault_test_3.csv',index=False)  
df_orf
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\1025717972.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_orf['Fault']=fault
#                        Max    Min      Mean       Std       RMS  Skewness  \
# 2004-04-15 12:32:00  0.315 -0.300 -0.002260  0.071999  0.072032 -0.017350
# 2004-04-15 12:42:00  0.278 -0.320 -0.000929  0.071960  0.071965 -0.020822
# 2004-04-15 12:52:00  0.403 -0.300 -0.001721  0.071967  0.071986  0.009853
# 2004-04-15 13:02:00  0.334 -0.332 -0.001242  0.070479  0.070488  0.037436
# 2004-04-15 13:12:00  0.295 -0.334 -0.002482  0.072242  0.072283 -0.030286
# ...                    ...    ...       ...       ...       ...       ...
# 2004-04-18 00:02:00  2.280 -3.936 -0.001821  0.394083  0.394077 -0.416217
# ...

# %% [markdown]
# # Collect The Normal Data From all the bearings

# %%
Test=[1,2,3]
Bearing_No=[1,2,3,4]

df_normal_bearing = pd.DataFrame()

for test_no in Test:
    for bearing_no in Bearing_No:
        temp = pd.read_csv("database\\tratados\\Time_feature_matrix_Bearing_{}_Test_{}.csv".format(bearing_no,test_no),index_col='Unnamed: 0')

        starting = np.floor(len(temp)*.21)
        ending = np.floor(len(temp)*.23)

        start_time = temp.index[starting]
        end_time = temp.index[ending]

        temp = temp[start_time:end_time]
        
        df_normal_bearing=df_normal_bearing.append(temp)

fault=[]
for i in range (0,len(df_normal_bearing)):
    fault.append('Normal')

df_normal_bearing['Fault']=fault

df_normal_bearing.to_csv('database\\tratados\\Normal_Bearing.csv',index=False)
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\3277948908.py:13: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   start_time = temp.index[starting]
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\3277948908.py:14: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
#   end_time = temp.index[ending]
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\3277948908.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_normal_bearing=df_normal_bearing.append(temp)
# C:\Users\leona\AppData\Local\Temp\ipykernel_1728\3277948908.py:13: FutureWarning: Indexing with a float is deprecated, and will raise an IndexError in pandas 2.0. You can manually convert to an integer key instead.
# ...

# %%
df_normal_bearing
# Out:
#                        Max    Min      Mean       Std       RMS  Skewness  \
# 2003-11-01 14:11:00  0.422 -0.657 -0.117744  0.093095  0.150100 -0.033307
# 2003-11-01 14:21:00  0.466 -0.605 -0.116695  0.091405  0.148230  0.022064
# 2003-11-01 14:31:00  0.356 -0.713 -0.117174  0.094340  0.150430 -0.088984
# 2003-11-01 14:41:00  0.500 -0.647 -0.117876  0.093033  0.150165 -0.036459
# 2003-11-01 14:51:00  0.479 -0.659 -0.116594  0.093409  0.149395 -0.002756
# ...                    ...    ...       ...       ...       ...       ...
# 2004-03-14 11:02:00  0.276 -0.244 -0.003381  0.051343  0.051453  0.050065
# 2004-03-14 11:12:00  0.244 -0.295 -0.002698  0.051048  0.051118 -0.017866
# 2004-03-14 11:22:00  0.234 -0.222 -0.003480  0.051675  0.051791  0.039894
# 2004-03-14 11:32:00  0.225 -0.212 -0.003334  0.052118  0.052223  0.005201
# 2004-03-14 11:42:00  0.349 -0.239 -0.002436  0.051808  0.051864  0.030514
#
#                      Kurtosis  Crest Factor  Form Factor   Fault
# ...
